# %%
import pandas as pd
import numpy as np
import scipy
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scipy.stats import norm

# %%
# Specifying the directories and paths
working_folder = "."

figures_folder = working_folder + os.path.sep + 'figures' + os.path.sep
if not os.path.isdir(figures_folder):
    os.mkdir(figures_folder)
    
data_folder = working_folder + os.path.sep + 'data' + os.path.sep # ./data/


#'./data/asos_digital_experiments_dataset.parquet'
abtest_metrics_local_path = data_folder + 'asos_digital_experiments_dataset.parquet' 
abtest_metrics_remote_path = "https://osf.io/62t7f/download" 

# Download the dataset if it does not already exist
# The body of the if-statement is a shell command
if not os.path.exists(abtest_metrics_local_path):
    # !wget -O $abtest_metrics_local_path $abtest_metrics_remote_path

# Load the dataset
df = pd.read_parquet(abtest_metrics_local_path)

# %%
df
# Out:
#       experiment_id  variant_id  metric_id  time_since_start    count_c  \
# 0            036afc           2          1               1.5   188065.0
# 1            036afc           2          1               2.0   245041.0
# 2            036afc           2          1               2.5   277237.0
# 3            036afc           2          1               3.0   315689.0
# 4            036afc           2          1               3.5   338631.0
# ...             ...         ...        ...               ...        ...
# 24148        fdaf62           1          4              28.0  2182559.0
# 24149        fdaf62           1          4              29.0  2259937.0
# 24150        fdaf62           1          4              30.0  2341537.0
# 24151        fdaf62           1          4              31.0  2422152.0
# 24152        fdaf62           1          4              32.0  2478580.0
#
#          count_t     mean_c     mean_t   variance_c   variance_t
# 0       186686.0   0.107808   0.107828     0.096186     0.096201
# 1       243694.0   0.131790   0.131435     0.114422     0.114160
# 2       275949.0   0.143065   0.142711     0.122598     0.122345
# 3       314676.0   0.161789   0.160997     0.135613     0.135077
# 4       337715.0   0.172474   0.171067     0.142727     0.141803
# ...          ...        ...        ...          ...          ...
# 24148  2180705.0  38.270483  38.858464  8478.894092  8708.839083
# 24149  2257899.0  38.485748  39.065107  8627.264583  8821.982824
# 24150  2339309.0  38.691410  39.211843  8916.435308  8848.559719
# 24151  2419745.0  38.705264  39.263485  8836.078773  8884.955277
# 24152  2475916.0  38.962364  39.554518  9077.322251  9215.231273
#
# [24153 rows x 10 columns]

# %% [markdown]
# ### Quantos experimentos têm a metrica 1 / binaria?

# %%
df.loc[(df['metric_id'] == 1)]['experiment_id'].unique()
# Out:
# array(['036afc', '058875', '08bcc2', '0bad33', '11cf0c', '162a38',
#        '1bacbe', '2203f3', '26bd38', '2c8a04', '329386', '3683df',
#        '39aed1', '3b4300', '3b62b9', '3c9dfd', '3da1aa', '3fef62',
#        '449c53', '4509ec', '47a23b', '48a675', '4db6c7', '51c502',
#        '530a76', '54a85a', '591c2c', '5ca6d6', '64dc88', '65c732',
#        '6c4737', '6f8a33', '79f97f', '7a99e4', '7cd85b', '81761c',
#        '834947', '84f653', '873d9d', '87f410', '8b436e', '8e0f8a',
#        '8e2cb6', '8ed19a', '9b959e', '9ed9d5', 'a1e2bf', 'a4386f',
#        'a68bf4', 'adea31', 'b2da2e', 'b3280a', 'b382c6', 'b8a409',
#        'bac0d3', 'c3d89d', 'c4df76', 'c56288', 'c74b98', 'cf1b96',
#        'd0b910', 'd4287a', 'd53f0e', 'd54896', 'd6e1d7', 'd8f486',
#        'db7752', 'df31d1', 'e4b7b9', 'e4c4a1', 'e861d3', 'e90dd1',
#        'ee6ff7', 'eeefa3', 'f0df06', 'f50b07', 'fcebce', 'fdaf62'],
#       dtype=object)

# %%
metric1 = df.loc[(df['metric_id'] == 1)]
exp_counts = metric1['experiment_id'].value_counts().sort_values(ascending= False)
exp_id = exp_counts.idxmax()
exp_counts
# Out:
# experiment_id
# 54a85a    288
# 2c8a04    246
# 81761c    232
# b382c6    212
# 329386    198
#          ...
# 591c2c     12
# b2da2e      8
# cf1b96      7
# a1e2bf      4
# 84f653      2
# Name: count, Length: 78, dtype: int64

# %%
new_df = metric1[metric1['experiment_id'] == exp_id].sort_values('time_since_start',ascending=False); new_df
# Out:
#      experiment_id  variant_id  metric_id  time_since_start    count_c  \
# 8459        54a85a           1          1              55.5  3320536.0
# 8075        54a85a           0          1              55.5  3320536.0
# 8843        54a85a           2          1              55.5  3320536.0
# 8458        54a85a           1          1              55.0  3320412.0
# 8074        54a85a           0          1              55.0  3320412.0
# ...            ...         ...        ...               ...        ...
# 7981        54a85a           0          1               7.0  1226360.0
# 8749        54a85a           2          1               7.0  1226360.0
# 7980        54a85a           0          1               6.5  1148449.0
# 8748        54a85a           2          1               6.5  1148449.0
# 8364        54a85a           1          1               6.5  1148449.0
#
#         count_t    mean_c    mean_t  variance_c  variance_t
# 8459  3316730.0  0.251191  0.252204    0.188094    0.188597
# 8075   102316.0  0.251191  0.250538    0.188094    0.187768
# 8843  3320435.0  0.251191  0.250612    0.188094    0.187806
# 8458  3316611.0  0.250475  0.251480    0.187737    0.188238
# 8074   102312.0  0.250475  0.249795    0.187737    0.187397
# ...         ...       ...       ...         ...         ...
# 7981    37433.0  0.136382  0.135950    0.117782    0.117467
# 8749  1226572.0  0.136382  0.134953    0.117782    0.116741
# 7980    35048.0  0.126048  0.125342    0.110160    0.109632
# 8748  1148325.0  0.126048  0.124925    0.110160    0.109318
# 8364  1148465.0  0.126048  0.125872    0.110160    0.110029
#
# [288 rows x 10 columns]

# %%
exp_id = '54a85a'
sub_df = df[(df["experiment_id"] == exp_id) & (df["metric_id"] == 1)]
df_ord = sub_df.sort_values("time_since_start")

plt.figure(figsize=(10,5))
# Plotar evolução da média
plt.plot(df_ord["time_since_start"], df_ord["mean_t"], label="Tratamento")
plt.plot(df_ord["time_since_start"], df_ord["mean_c"], label="Controle")
plt.xlabel("Dias desde o início")
plt.ylabel("Média acumulada")
plt.title(f"Evolução das médias - Experimento {exp_id}")
# plt.axvline (x=55.5, color='r',linestyle = '--') 
# sns.lineplot(x=[55.5], y=[0.252], marker='o', markersize=7, color='r')
plt.legend()
plt.show()

# %%
new_df.iloc[0] # ultimo timestemp, mais tempo desde o incicio, mais dados
# Out:
# experiment_id          54a85a
# variant_id                  1
# metric_id                   1
# time_since_start         55.5
# count_c             3320536.0
# count_t             3316730.0
# mean_c               0.251191
# mean_t               0.252204
# variance_c           0.188094
# variance_t           0.188597
# Name: 8459, dtype: object

# %%
row = new_df.iloc[0]

count_c = row['count_c']
count_t = row['count_t']
mean_c = row['mean_c']
mean_t = row['mean_t']
variance_c = row['variance_c']
variance_t = row['variance_t']

# %% [markdown]
# Para calcuar o erro padrão entre as duas médias:
#
# $SE = \sqrt{\frac{s^2_c}{n_c}+\frac{s^2_t}{c_t}}$

# %%
SE = np.sqrt((variance_c/count_c)+(variance_t/count_t))
print(f'Standard Error: {SE}')
# Out:
# Standard Error: 0.0003369097700431301

# %% [markdown]
# Calculando a estatistica Z:
#
# $Z_{score} = \frac{\bar{x}_t - \bar{x}_c}{SE}$

# %%
Z = (mean_t- mean_c)/SE
print(f'Z score: {Z}')
# Out:
# Z score: 3.006906995504404

# %%
p_valor = 2 * (1-norm.cdf(abs(Z)))
print(f'P-valor: {p_valor}')
# Out:
# P-valor: 0.0026392049550985064

# %%
# Plot da distribuição normal padrão com o valor de Z marcado
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label='Distribuição Normal Padrão')
plt.axvline(Z, color='red', linestyle='--', label=f'Z = {Z:.2f}')
plt.axvline(-Z, color='red', linestyle='--')
plt.fill_between(x, y, where=(abs(x) >= abs(Z)), color='red', alpha=0.2, label=f'p = {p_valor:.4f}')
plt.title("Visualização do Z-score e P-valor")
plt.xlabel("Z")
plt.ylabel("Densidade de probabilidade")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modularizando testes

# %%
def sezp_report(df, metrica: int, exp_list: list, nivel=0.95):
    metric_df = df[df['metric_id'] == metrica]
    summary_res = []

    for exp_id in exp_list:
        new_df = metric_df[metric_df['experiment_id'] == exp_id].sort_values('time_since_start', ascending=False)
        if new_df.empty:
            continue
        
        row = new_df.iloc[0]

        count_c = row['count_c']
        count_t = row['count_t']
        mean_c = row['mean_c']
        mean_t = row['mean_t']
        var_c = row['variance_c']
        var_t = row['variance_t']

        effect_size = mean_t - mean_c
        effect_percent = 100 * (effect_size / mean_c) if mean_c > 0 else np.nan

        se = np.sqrt((var_c / count_c) + (var_t / count_t))
        z_score = (mean_t - mean_c) / se
        p_valor = 2 * (1 - norm.cdf(abs(z_score)))

        ic_z = norm.ppf(1 - (1 - nivel) / 2)
        ic_inf = effect_size - (ic_z * se)
        ic_sup = effect_size + (ic_z * se)

        significant = p_valor < 0.05

        # interpretação automática
        if significant:
            if effect_size > 0:
                interpretacao = "Aumento significativo na métrica."
            else:
                interpretacao = "Redução significativa na métrica."
        else:
            interpretacao = "Inconclusivo: sem diferença estatística detectada."

        summary_res.append({
            'Experiment ID': exp_id,
            'Métrica': metrica,
            'Tempo Final (dias)': row['time_since_start'],
            'Taxa Controle': round(mean_c, 4),
            'Taxa Tratamento': round(mean_t, 4),
            'Dif. Absoluta': round(effect_size, 4),
            'Dif. Relativa (%)': f"{effect_percent:.2f}%",
            'IC 95% (Inf)': round(ic_inf, 4),
            'IC 95% (Sup)': round(ic_sup, 4),
            'Z-Score': round(z_score, 4),
            'P-Valor': round(p_valor, 6),
            'Significativo': "Yes" if significant else "No",
            'interpretação': interpretacao

        })

    report_df = pd.DataFrame(summary_res)
    return report_df

# %%
report_df.sample(20).sort_values('P-Valor', ascending= True)
# Out:
#    Experiment ID  Métrica  Tempo Final (dias)  Taxa Controle  Taxa Tratamento  \
# 19        4509ec        1                28.5         0.0569           0.0559
# 9         2c8a04        1               131.0         0.0630           0.0642
# 69        e4c4a1        1                36.0         0.1856           0.1841
# 25        54a85a        1                55.5         0.2512           0.2522
# 55        c3d89d        1                39.0         0.0493           0.0490
# 40        8b436e        1                45.5         0.0468           0.0469
# 1         058875        1                21.5         0.0456           0.0457
# 60        d0b910        1                32.5         0.2058           0.2054
# 28        64dc88        1                37.5         0.0633           0.0632
# 65        d8f486        1                34.0         0.2065           0.2063
# 52        b382c6        1                60.5         0.2459           0.2450
# 24        530a76        1                54.0         0.0379           0.0379
# 56        c4df76        1                31.5         0.0491           0.0491
# 14        3b62b9        1                88.0         0.2998           0.2996
# 71        e90dd1        1                47.5         0.1927           0.1926
# 59        cf1b96        1                94.5         0.3444           0.3445
# 10        329386        1                91.0         0.2204           0.2204
# 5         162a38        1                42.0         0.2617           0.2617
# 73        eeefa3        1                13.0         0.2103           0.2103
# 66        db7752        1                42.0         0.2153           0.2153
#
#     Dif. Absoluta Dif. Relativa (%)  IC 95% (Inf)  IC 95% (Sup)  Z-Score  \
# 19        -0.0009            -1.67%       -0.0011       -0.0008 -15.5230
# 9          0.0012             1.94%        0.0011        0.0013  28.5835
# 69        -0.0016            -0.84%       -0.0022       -0.0009  -4.8412
# 25         0.0010             0.40%        0.0004        0.0017   3.0069
# 55        -0.0002            -0.50%       -0.0005        0.0000  -1.8820
# 40         0.0001             0.16%       -0.0000        0.0002   1.4739
# 1          0.0001             0.22%       -0.0000        0.0002   1.4601
# 60        -0.0003            -0.16%       -0.0008        0.0002  -1.3102
# 28        -0.0001            -0.14%       -0.0003        0.0001  -0.9677
# 65        -0.0003            -0.13%       -0.0008        0.0003  -0.9502
# 52        -0.0009            -0.38%       -0.0031        0.0012  -0.8603
# 24         0.0000             0.07%       -0.0000        0.0001   0.7119
# 56        -0.0000            -0.09%       -0.0002        0.0001  -0.6614
# 14        -0.0002            -0.07%       -0.0010        0.0005  -0.5953
# 71        -0.0001            -0.08%       -0.0008        0.0005  -0.4227
# 59         0.0001             0.03%       -0.0007        0.0009   0.2827
# 10         0.0000             0.02%       -0.0005        0.0006   0.1493
# 5         -0.0000            -0.02%       -0.0007        0.0006  -0.1219
# 73         0.0001             0.03%       -0.0011        0.0012   0.0923
# 66         0.0000             0.00%       -0.0005        0.0005   0.0046
#
#      P-Valor Significativo                                      interpretação
# 19  0.000000           Yes                  Redução significativa na métrica.
# 9   0.000000           Yes                  Aumento significativo na métrica.
# 69  0.000001           Yes                  Redução significativa na métrica.
# 25  0.002639           Yes                  Aumento significativo na métrica.
# 55  0.059838            No  Inconclusivo: sem diferença estatística detect...
# 40  0.140514            No  Inconclusivo: sem diferença estatística detect...
# 1   0.144249            No  Inconclusivo: sem diferença estatística detect...
# 60  0.190113            No  Inconclusivo: sem diferença estatística detect...
# 28  0.333173            No  Inconclusivo: sem diferença estatística detect...
# 65  0.342010            No  Inconclusivo: sem diferença estatística detect...
# 52  0.389634            No  Inconclusivo: sem diferença estatística detect...
# 24  0.476553            No  Inconclusivo: sem diferença estatística detect...
# 56  0.508334            No  Inconclusivo: sem diferença estatística detect...
# 14  0.551640            No  Inconclusivo: sem diferença estatística detect...
# 71  0.672509            No  Inconclusivo: sem diferença estatística detect...
# 59  0.777373            No  Inconclusivo: sem diferença estatística detect...
# 10  0.881310            No  Inconclusivo: sem diferença estatística detect...
# 5   0.902958            No  Inconclusivo: sem diferença estatística detect...
# 73  0.926467            No  Inconclusivo: sem diferença estatística detect...
# 66  0.996333            No  Inconclusivo: sem diferença estatística detect...

# %%
report_df.loc[report_df['Experiment ID'] == '4db6c7']
# Out:
#    Experiment ID  Métrica  Tempo Final (dias)  Taxa Controle  Taxa Tratamento  \
# 22        4db6c7        1                32.0          0.495           0.4935
#
#     Dif. Absoluta Dif. Relativa (%)  IC 95% (Inf)  IC 95% (Sup)  Z-Score  \
# 22        -0.0016            -0.31%       -0.0032        0.0001  -1.8732
#
#      P-Valor Significativo                                      interpretação
# 22  0.061037            No  Inconclusivo: sem diferença estatística detect...

# %%
total_exp  = list(df.loc[(df['metric_id'] == 1)]['experiment_id'].unique())
exp_list = total_exp
report_df = sezp_report(df,metrica = 1, exp_list = exp_list);
report_df.head(60).sort_values('P-Valor',ascending=True)
# Out:
#    Experiment ID  Métrica  Tempo Final (dias)  Taxa Controle  Taxa Tratamento  \
# 9         2c8a04        1               131.0         0.0630           0.0642
# 19        4509ec        1                28.5         0.0569           0.0559
# 35        81761c        1               118.5         0.2618           0.2654
# 32        79f97f        1                53.0         0.5568           0.5663
# 51        b3280a        1                34.5         0.2001           0.2049
# 44        9b959e        1                15.5         0.0460           0.0452
# 15        3c9dfd        1                30.5         0.1959           0.1971
# 47        a4386f        1                89.0         0.2868           0.2878
# 31        6f8a33        1               118.5         0.3078           0.3091
# 25        54a85a        1                55.5         0.2512           0.2522
# 38        873d9d        1                45.5         0.0469           0.0468
# 45        9ed9d5        1                30.5         0.1917           0.1924
# 12        39aed1        1                22.5         0.0373           0.0371
# 8         26bd38        1                46.5         0.1518           0.1524
# 57        c56288        1                35.5         0.2437           0.2443
# 53        b8a409        1                64.5         0.2449           0.2458
# 55        c3d89d        1                39.0         0.0493           0.0490
# 22        4db6c7        1                32.0         0.4950           0.4935
# 21        48a675        1                67.5         0.1996           0.2004
# 40        8b436e        1                45.5         0.0468           0.0469
# 1         058875        1                21.5         0.0456           0.0457
# 6         1bacbe        1                45.0         0.0469           0.0469
# 7         2203f3        1                42.5         0.3010           0.3016
# 3         0bad33        1                45.5         0.2187           0.2191
# 11        3683df        1                68.5         0.0458           0.0458
# 27        5ca6d6        1                44.0         0.5355           0.5378
# 18        449c53        1                64.5         0.2459           0.2463
# 17        3fef62        1                71.5         0.3102           0.3109
# 26        591c2c        1                12.5         0.1930           0.1966
# 23        51c502        1                43.5         0.2297           0.2302
# 49        adea31        1                84.5         0.0384           0.0383
# 28        64dc88        1                37.5         0.0633           0.0632
# 4         11cf0c        1                64.5         0.0471           0.0472
# 42        8e2cb6        1                18.5         0.1148           0.1151
# 52        b382c6        1                60.5         0.2459           0.2450
# 39        87f410        1                39.5         0.2355           0.2351
# 20        47a23b        1                43.5         0.2150           0.2153
# 2         08bcc2        1                19.5         0.2409           0.2405
# 0         036afc        1                76.5         0.5868           0.5873
# 24        530a76        1                54.0         0.0379           0.0379
# 56        c4df76        1                31.5         0.0491           0.0491
# 30        6c4737        1                32.5         0.1826           0.1824
# 14        3b62b9        1                88.0         0.2998           0.2996
# 33        7a99e4        1                45.0         0.0469           0.0469
# 54        bac0d3        1                35.0         0.2766           0.2763
# 29        65c732        1                60.5         0.5831           0.5827
# 13        3b4300        1                39.5         0.1403           0.1406
# 41        8e0f8a        1                49.5         0.2483           0.2482
# 50        b2da2e        1                 3.0         0.0765           0.0768
# 58        c74b98        1                58.0         0.1846           0.1848
# 43        8ed19a        1                44.5         0.0322           0.0322
# 16        3da1aa        1                26.5         0.2005           0.2005
# 59        cf1b96        1                94.5         0.3444           0.3445
# 46        a1e2bf        1                 2.5         0.0348           0.0348
# 34        7cd85b        1                45.0         0.2257           0.2256
# 10        329386        1                91.0         0.2204           0.2204
# 48        a68bf4        1                30.5         0.0392           0.0392
# 5         162a38        1                42.0         0.2617           0.2617
# 37        84f653        1                 2.0         0.0483           0.0482
# 36        834947        1                43.5         0.0777           0.0777
#
#     Dif. Absoluta Dif. Relativa (%)  IC 95% (Inf)  IC 95% (Sup)  Z-Score  \
# 9          0.0012             1.94%        0.0011        0.0013  28.5835
# 19        -0.0009            -1.67%       -0.0011       -0.0008 -15.5230
# 35         0.0036             1.39%        0.0030        0.0043  10.6421
# 32         0.0095             1.70%        0.0084        0.0106  16.8227
# 51         0.0048             2.41%        0.0042        0.0055  14.8925
# 44        -0.0008            -1.71%       -0.0009       -0.0006 -10.0180
# 15         0.0011             0.57%        0.0005        0.0017   3.8333
# 47         0.0010             0.34%        0.0004        0.0015   3.4269
# 31         0.0012             0.40%        0.0005        0.0020   3.3288
# 25         0.0010             0.40%        0.0004        0.0017   3.0069
# 38        -0.0001            -0.28%       -0.0002       -0.0000  -2.5197
# 45         0.0006             0.34%        0.0001        0.0012   2.4144
# 12        -0.0001            -0.39%       -0.0003       -0.0000  -2.2295
# 8          0.0006             0.38%        0.0001        0.0011   2.1954
# 57         0.0007             0.27%        0.0000        0.0013   2.1024
# 53         0.0010             0.39%        0.0000        0.0019   2.0226
# 55        -0.0002            -0.50%       -0.0005        0.0000  -1.8820
# 22        -0.0016            -0.31%       -0.0032        0.0001  -1.8732
# 21         0.0008             0.41%       -0.0001        0.0017   1.7742
# 40         0.0001             0.16%       -0.0000        0.0002   1.4739
# 1          0.0001             0.22%       -0.0000        0.0002   1.4601
# 6         -0.0001            -0.17%       -0.0002        0.0000  -1.4169
# 7          0.0006             0.21%       -0.0003        0.0016   1.3651
# 3          0.0004             0.17%       -0.0002        0.0009   1.3607
# 11        -0.0001            -0.13%       -0.0001        0.0000  -1.3282
# 27         0.0023             0.43%       -0.0011        0.0057   1.3207
# 18         0.0003             0.13%       -0.0002        0.0008   1.2550
# 17         0.0007             0.22%       -0.0004        0.0018   1.2541
# 26         0.0036             1.87%       -0.0023        0.0095   1.1992
# 23         0.0006             0.25%       -0.0004        0.0016   1.1057
# 49        -0.0000            -0.10%       -0.0001        0.0000  -0.9780
# 28        -0.0001            -0.14%       -0.0003        0.0001  -0.9677
# 4          0.0000             0.09%       -0.0000        0.0001   0.9388
# 42         0.0003             0.22%       -0.0003        0.0008   0.9302
# 52        -0.0009            -0.38%       -0.0031        0.0012  -0.8603
# 39        -0.0004            -0.16%       -0.0013        0.0005  -0.8539
# 20         0.0003             0.13%       -0.0004        0.0009   0.8374
# 2         -0.0004            -0.17%       -0.0014        0.0006  -0.7973
# 0          0.0005             0.09%       -0.0008        0.0018   0.7458
# 24         0.0000             0.07%       -0.0000        0.0001   0.7119
# 56        -0.0000            -0.09%       -0.0002        0.0001  -0.6614
# 30        -0.0002            -0.11%       -0.0008        0.0004  -0.6268
# 14        -0.0002            -0.07%       -0.0010        0.0005  -0.5953
# 33         0.0000             0.09%       -0.0001        0.0002   0.5922
# 54        -0.0002            -0.08%       -0.0010        0.0005  -0.5724
# 29        -0.0004            -0.08%       -0.0022        0.0013  -0.5066
# 13         0.0003             0.23%       -0.0010        0.0016   0.4752
# 41        -0.0001            -0.05%       -0.0006        0.0004  -0.4509
# 50         0.0003             0.37%       -0.0010        0.0015   0.4390
# 58         0.0002             0.09%       -0.0006        0.0009   0.4117
# 43         0.0000             0.06%       -0.0001        0.0001   0.4005
# 16         0.0001             0.05%       -0.0004        0.0006   0.3495
# 59         0.0001             0.03%       -0.0007        0.0009   0.2827
# 46         0.0000             0.11%       -0.0003        0.0003   0.2609
# 34        -0.0001            -0.03%       -0.0007        0.0006  -0.1621
# 10         0.0000             0.02%       -0.0005        0.0006   0.1493
# 48        -0.0000            -0.02%       -0.0001        0.0001  -0.1429
# 5         -0.0000            -0.02%       -0.0007        0.0006  -0.1219
# 37        -0.0000            -0.10%       -0.0015        0.0014  -0.0625
# 36        -0.0000            -0.01%       -0.0002        0.0002  -0.0428
#
#      P-Valor Significativo                                      interpretação
# 9   0.000000           Yes                  Aumento significativo na métrica.
# 19  0.000000           Yes                  Redução significativa na métrica.
# 35  0.000000           Yes                  Aumento significativo na métrica.
# 32  0.000000           Yes                  Aumento significativo na métrica.
# 51  0.000000           Yes                  Aumento significativo na métrica.
# 44  0.000000           Yes                  Redução significativa na métrica.
# 15  0.000126           Yes                  Aumento significativo na métrica.
# 47  0.000611           Yes                  Aumento significativo na métrica.
# 31  0.000872           Yes                  Aumento significativo na métrica.
# 25  0.002639           Yes                  Aumento significativo na métrica.
# 38  0.011746           Yes                  Redução significativa na métrica.
# 45  0.015762           Yes                  Aumento significativo na métrica.
# 12  0.025780           Yes                  Redução significativa na métrica.
# 8   0.028135           Yes                  Aumento significativo na métrica.
# 57  0.035515           Yes                  Aumento significativo na métrica.
# 53  0.043117           Yes                  Aumento significativo na métrica.
# 55  0.059838            No  Inconclusivo: sem diferença estatística detect...
# 22  0.061037            No  Inconclusivo: sem diferença estatística detect...
# 21  0.076032            No  Inconclusivo: sem diferença estatística detect...
# 40  0.140514            No  Inconclusivo: sem diferença estatística detect...
# 1   0.144249            No  Inconclusivo: sem diferença estatística detect...
# 6   0.156525            No  Inconclusivo: sem diferença estatística detect...
# 7   0.172214            No  Inconclusivo: sem diferença estatística detect...
# 3   0.173620            No  Inconclusivo: sem diferença estatística detect...
# 11  0.184099            No  Inconclusivo: sem diferença estatística detect...
# 27  0.186615            No  Inconclusivo: sem diferença estatística detect...
# 18  0.209494            No  Inconclusivo: sem diferença estatística detect...
# 17  0.209799            No  Inconclusivo: sem diferença estatística detect...
# 26  0.230443            No  Inconclusivo: sem diferença estatística detect...
# 23  0.268839            No  Inconclusivo: sem diferença estatística detect...
# 49  0.328097            No  Inconclusivo: sem diferença estatística detect...
# 28  0.333173            No  Inconclusivo: sem diferença estatística detect...
# 4   0.347830            No  Inconclusivo: sem diferença estatística detect...
# 42  0.352270            No  Inconclusivo: sem diferença estatística detect...
# 52  0.389634            No  Inconclusivo: sem diferença estatística detect...
# 39  0.393183            No  Inconclusivo: sem diferença estatística detect...
# 20  0.402380            No  Inconclusivo: sem diferença estatística detect...
# 2   0.425305            No  Inconclusivo: sem diferença estatística detect...
# 0   0.455817            No  Inconclusivo: sem diferença estatística detect...
# 24  0.476553            No  Inconclusivo: sem diferença estatística detect...
# 56  0.508334            No  Inconclusivo: sem diferença estatística detect...
# 30  0.530796            No  Inconclusivo: sem diferença estatística detect...
# 14  0.551640            No  Inconclusivo: sem diferença estatística detect...
# 33  0.553694            No  Inconclusivo: sem diferença estatística detect...
# 54  0.567027            No  Inconclusivo: sem diferença estatística detect...
# 29  0.612454            No  Inconclusivo: sem diferença estatística detect...
# 13  0.634629            No  Inconclusivo: sem diferença estatística detect...
# 41  0.652055            No  Inconclusivo: sem diferença estatística detect...
# 50  0.660639            No  Inconclusivo: sem diferença estatística detect...
# 58  0.680563            No  Inconclusivo: sem diferença estatística detect...
# 43  0.688788            No  Inconclusivo: sem diferença estatística detect...
# 16  0.726739            No  Inconclusivo: sem diferença estatística detect...
# 59  0.777373            No  Inconclusivo: sem diferença estatística detect...
# 46  0.794147            No  Inconclusivo: sem diferença estatística detect...
# 34  0.871230            No  Inconclusivo: sem diferença estatística detect...
# 10  0.881310            No  Inconclusivo: sem diferença estatística detect...
# 48  0.886362            No  Inconclusivo: sem diferença estatística detect...
# 5   0.902958            No  Inconclusivo: sem diferença estatística detect...
# 37  0.950179            No  Inconclusivo: sem diferença estatística detect...
# 36  0.965824            No  Inconclusivo: sem diferença estatística detect...

# %%
report_df.loc[report_df['interpretação'] =='Redução significativa na métrica.']
# Out:
#    Experiment ID  Métrica  Tempo Final (dias)  Taxa Controle  Taxa Tratamento  \
# 12        39aed1        1                22.5         0.0373           0.0371
# 19        4509ec        1                28.5         0.0569           0.0559
# 38        873d9d        1                45.5         0.0469           0.0468
# 44        9b959e        1                15.5         0.0460           0.0452
# 63        d54896        1                38.0         0.0739           0.0736
# 69        e4c4a1        1                36.0         0.1856           0.1841
# 75        f50b07        1                26.0         0.7724           0.7697
#
#     Dif. Absoluta Dif. Relativa (%)  IC 95% (Inf)  IC 95% (Sup)  Z-Score  \
# 12        -0.0001            -0.39%       -0.0003       -0.0000  -2.2295
# 19        -0.0009            -1.67%       -0.0011       -0.0008 -15.5230
# 38        -0.0001            -0.28%       -0.0002       -0.0000  -2.5197
# 44        -0.0008            -1.71%       -0.0009       -0.0006 -10.0180
# 63        -0.0003            -0.40%       -0.0005       -0.0000  -2.2931
# 69        -0.0016            -0.84%       -0.0022       -0.0009  -4.8412
# 75        -0.0027            -0.35%       -0.0043       -0.0011  -3.2953
#
#      P-Valor Significativo                      interpretação
# 12  0.025780           Yes  Redução significativa na métrica.
# 19  0.000000           Yes  Redução significativa na métrica.
# 38  0.011746           Yes  Redução significativa na métrica.
# 44  0.000000           Yes  Redução significativa na métrica.
# 63  0.021844           Yes  Redução significativa na métrica.
# 69  0.000001           Yes  Redução significativa na métrica.
# 75  0.000983           Yes  Redução significativa na métrica.

# %%
report_df.loc[report_df['Experiment ID'] =='f50b07']
# Out:
#    Experiment ID  Métrica  Tempo Final (dias)  Taxa Controle  Taxa Tratamento  \
# 75        f50b07        1                26.0         0.7724           0.7697
#
#     Dif. Absoluta Dif. Relativa (%)  IC 95% (Inf)  IC 95% (Sup)  Z-Score  \
# 75        -0.0027            -0.35%       -0.0043       -0.0011  -3.2953
#
#      P-Valor Significativo                      interpretação
# 75  0.000983           Yes  Redução significativa na métrica.

# %%
report_df['interpretação'].value_counts()
# Out:
# interpretação
# Inconclusivo: sem diferença estatística detectada.    57
# Aumento significativo na métrica.                     14
# Redução significativa na métrica.                      7
# Name: count, dtype: int64

# %%
def plot_forest(df, top_n=10):
    plot_df = df.copy().sort_values('P-Valor').head(top_n)
    plt.figure(figsize=(8, top_n * 0.6))

    y = range(len(plot_df))
    plt.errorbar(
        plot_df['Dif. Absoluta'], y,
        xerr=[
            plot_df['Dif. Absoluta'] - plot_df['IC 95% (Inf)'],
            plot_df['IC 95% (Sup)'] - plot_df['Dif. Absoluta']
        ],
        fmt='o', color='black', ecolor='gray', capsize=4
    )

    plt.yticks(y, plot_df['Experiment ID'])
    plt.axvline(0, color='red', linestyle='--', label='Sem efeito')
    plt.xlabel('Diferença Absoluta (Trat - Controle)')
    plt.ylabel('Experimentos')
    # Ajuste dinâmico dos xticks com base no menor IC 95% (Inf)
    min_ic_inf = plot_df['IC 95% (Inf)'].min()
    max_ic_sup = plot_df['IC 95% (Sup)'].max()

    xtick_start = np.floor(min_ic_inf * 1000) / 1000 - 0.001  # Ajuste para incluir um pequeno buffer
    xtick_end = np.ceil(max_ic_sup * 1000) / 1000 + 0.001    # Ajuste para incluir um pequeno buffer
    xticks = np.arange(xtick_start, xtick_end + 0.001, 0.001)
    plt.xticks(xticks,rotation=-45)
    plt.title('Forest Plot – Efeito e IC 95% por experimento')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_forest(report_df,30)

# %%
report_df.columns
# Out:
# Index(['Experiment ID', 'Métrica', 'Tempo Final (dias)', 'Taxa Controle',
#        'Taxa Tratamento', 'Dif. Absoluta', 'Dif. Relativa (%)', 'IC 95% (Inf)',
#        'IC 95% (Sup)', 'Z-Score', 'P-Valor', 'Significativo', 'interpretação'],
#       dtype='object')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,6))


bins = 30

plt.subplot(1,2,1)
sns.histplot(report_df['Dif. Absoluta'],bins = bins,kde= True)
plt.title('Diferença (effect size) x Testes')
plt.ylabel('Frequeência')
plt. axvline (x=0, color='r',linestyle = '--') 
plt.grid(True)

plt.subplot(1,2,2)
sns.histplot(report_df['Z-Score'],bins = bins,kde= True)
plt.title('Z-Scores x Teste')
plt.ylabel('Frequeência')
plt.xticks(np.arange(report_df['Z-Score'].min(),report_df['Z-Score'].max(), 5))
plt. axvline (x=0, color='r',linestyle = '--') 
plt.grid(True)


# plt.subplot(2,1,2)
# plt.scatter(report_df['Dif. Absoluta'],report_df['Z-Score'])
# plt.grid()

# plt.tight_layout()
# plt.show()
